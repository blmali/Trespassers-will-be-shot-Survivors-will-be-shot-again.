# %%
import numpy as np
import pandas as pd
import seaborn as sns                  # For data visualization 
import matplotlib.pyplot as plt        # For plotting graphs 
# %matplotlib inline 
import warnings    
train=pd.read_csv("data_train.csv")

# %%
test=pd.read_csv("data_test.csv")
train["feature-1"]=train["feature-1"].replace(0.0,train['feature-1'].mean())
train["feature-2"]=train["feature-2"].replace(0.0,train['feature-2'].mean())
train["feature-3"]=train["feature-3"].replace(0.0,train['feature-3'].mean())
train["feature-4"]=train["feature-4"].replace(0.0,train['feature-4'].mean())
train["feature-5"]=train["feature-5"].replace(0.0,train['feature-5'].mean())
train["feature-6"]=train["feature-6"].replace(0.0,train['feature-6'].mean())
train["feature-7"]=train["feature-7"].replace(0.0,train['feature-7'].mean())
train["feature-8"]=train["feature-8"].replace(0.0,train['feature-8'].mean())
train["feature-9"]=train["feature-9"].replace(0.0,train['feature-9'].mean())
train["feature-10"]=train["feature-10"].replace(0.0,train['feature-10'].mean())

test["feature-1"]=test["feature-1"].replace(0.0,test['feature-1'].mean())
test["feature-2"]=test["feature-2"].replace(0.0,test['feature-2'].mean())
test["feature-3"]=test["feature-3"].replace(0.0,test['feature-3'].mean())
test["feature-4"]=test["feature-4"].replace(0.0,test['feature-4'].mean())
test["feature-5"]=test["feature-5"].replace(0.0,test['feature-5'].mean())
test["feature-6"]=test["feature-6"].replace(0.0,test['feature-6'].mean())
test["feature-7"]=test["feature-7"].replace(0.0,test['feature-7'].mean())
test["feature-8"]=test["feature-8"].replace(0.0,test['feature-8'].mean())
test["feature-9"]=test["feature-9"].replace(0.0,test['feature-9'].mean())
test["feature-10"]=test["feature-10"].replace(0.0,test['feature-10'].mean())

# %%
"""
train["feature-1"]=(train["feature-1"]-train["feature-1"].min())*1000/(train["feature-1"].max()-train["feature-1"].min())
train["feature-2"]=(train["feature-2"]-train["feature-2"].min())*1000/(train["feature-2"].max()-train["feature-2"].min())
train["feature-3"]=(train["feature-3"]-train["feature-3"].min())*1000/(train["feature-3"].max()-train["feature-3"].min())
train["feature-4"]=(train["feature-4"]-train["feature-4"].min())*1000/(train["feature-4"].max()-train["feature-4"].min())
train["feature-5"]=(train["feature-5"]-train["feature-5"].min())*1000/(train["feature-5"].max()-train["feature-5"].min())
train["feature-6"]=(train["feature-6"]-train["feature-6"].min())*1000/(train["feature-6"].max()-train["feature-6"].min())
train["feature-7"]=(train["feature-7"]-train["feature-7"].min())*1000/(train["feature-7"].max()-train["feature-7"].min())
train["feature-8"]=(train["feature-8"]-train["feature-8"].min())*1000/(train["feature-8"].max()-train["feature-8"].min())
train["feature-9"]=(train["feature-9"]-train["feature-9"].min())*1000/(train["feature-9"].max()-train["feature-9"].min())
train["feature-10"]=(train["feature-10"]-train["feature-10"].min())*1000/(train["feature-10"].max()-train["feature-10"].min())

test["feature-10"]=(test["feature-10"]-test["feature-10"].min())*1000/(test["feature-10"].max()-test["feature-10"].min())
test["feature-1"]=(test["feature-1"]-test["feature-1"].min())*1000/(test["feature-1"].max()-test["feature-1"].min())
test["feature-2"]=(test["feature-2"]-test["feature-2"].min())*1000/(test["feature-2"].max()-test["feature-2"].min())
test["feature-3"]=(test["feature-3"]-test["feature-3"].min())*1000/(test["feature-3"].max()-test["feature-3"].min())
test["feature-4"]=(test["feature-4"]-test["feature-4"].min())*1000/(test["feature-4"].max()-test["feature-4"].min())
test["feature-5"]=(test["feature-5"]-test["feature-5"].min())*1000/(test["feature-5"].max()-test["feature-5"].min())
test["feature-6"]=(test["feature-6"]-test["feature-6"].min())*1000/(test["feature-6"].max()-test["feature-6"].min())
test["feature-7"]=(test["feature-7"]-test["feature-7"].min())*1000/(test["feature-7"].max()-test["feature-7"].min())
test["feature-8"]=(test["feature-8"]-test["feature-8"].min())*1000/(test["feature-8"].max()-test["feature-8"].min())
test["feature-9"]=(test["feature-9"]-test["feature-9"].min())*1000/(test["feature-9"].max()-test["feature-9"].min())
"""
print("jhiee")
# Out:
# jhiee

# %%
#sns.distplot(train['feature-5']);
train.head(2)
# Out:
#    feature-1  feature-2  feature-3  feature-4  feature-5  feature-6  \
# 0  20.306201   7.246964  30.746074  70.738222  82.089549  44.537815
# 1  26.752616  16.396760  30.277686  39.271342  80.597014  31.302522
#
#    feature-7  feature-8  feature-9  feature-10  label
# 0  56.908667  17.261529  27.450978   42.425691      7
# 1  76.580799  50.305849  63.137250   29.514480      3

# %%
X=train.drop("label",axis=1)

# %%
X.head(40)
# Out:
#     feature-1  feature-2  feature-3  feature-4  feature-5  feature-6  \
# 0   20.306201   7.246964  30.746074  70.738222  82.089549  44.537815
# 1   26.752616  16.396760  30.277686  39.271342  80.597014  31.302522
# 2   23.448827  14.291499  31.549011  57.424320  86.567170  37.394956
# 3   21.998386  10.850202  32.920712  65.819695  86.567170  39.075630
# 4   26.188554  10.364373  31.381732  63.537360  98.507465  36.554622
# 5   22.643028  14.534414  32.251593  56.928355  86.567170  37.394956
# 6   21.676067   9.311740  33.221810  65.121158  86.567170  38.235296
# 7   26.188554  10.364373  31.381732  63.537360  98.507465  32.352941
# 8   21.353743  12.955467  32.452325  52.153518  86.567170  35.714288
# 9   22.804191  16.437245  29.307459  57.526555  86.567170  32.563026
# 10  26.027392   9.959514  31.247913  61.251853  98.507465  36.344537
# 11  22.804191  14.372469  32.853798  55.441722  62.686563  34.663864
# 12  24.335213  16.680159  29.708933  58.582746  86.567170  38.445380
# ...

# %%
y=train["label"]

# %%
y.head(2)
# Out:
# 0    7
# 1    3
# Name: label, dtype: int64

# %%
from sklearn import tree

# %%
model = tree.DecisionTreeClassifier()

# %%
from sklearn.model_selection import train_test_split
x_train, x_cv, y_train, y_cv = train_test_split(X,y, test_size =0.3)
from sklearn import linear_model
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import accuracy_score

model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
y_pred = model.predict(x_cv)
from sklearn import metrics
print(np.sqrt(metrics.mean_squared_error(y_cv, y_pred)))
# Out:
# 0.7251727987738835

# %%
pred_test1=[]
pred_test = model.predict(test)
submission=pd.read_csv("sample_submission.csv")
pd.DataFrame(pred_test).to_csv('logistic.csv',index=False,header=False)

# %%
pred_test.shape
# Out:
# (3000,)

# %%
test.shape
# Out:
# (3000, 10)
